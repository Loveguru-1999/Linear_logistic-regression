# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
car=pd.read_csv('seaborn-datasets/car_crashes.csv')

# %%
car.sample(3)
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 39   11.1     3.774    4.218          10.212        8.769      1148.99
# 28   14.7     5.439    4.704          13.965       14.553      1029.87
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
#
#     ins_losses
# 39      148.58
# 28      138.71
# 9       144.18

# %%
sns.heatmap(car.isnull()) #check for null spaces

# %%
sns.pairplot(car)

# %%
sns.distplot(car['alcohol'])

# %%
car.sample(2)
# Out:
#     Total  Speeding  Alcohol  Not_Distracted  No_Previous  Ins_Premium  \
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 18   20.5     7.175    6.765          14.965       20.090      1281.55
#
#     Ins_Losses
# 6       167.02
# 18      194.78

# %%
car.columns=car.columns.str.title()

# %%
from sklearn.model_selection import train_test_split

# %%
X=car.drop('Total',axis=1)
y=car['Total']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
ll=LinearRegression()

# %%
ll.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pre=ll.predict(X_test)

# %%
plt.scatter(pre,y_test)

# %%
sns.distplot((pre-y_test))

# %%
#For example
print(ll.predict([[4.968,3.888,9.396,8.856,1068.73,167.02]]))
# Out:
# [10.73197058]
